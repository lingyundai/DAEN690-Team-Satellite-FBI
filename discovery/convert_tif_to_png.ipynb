# %%
This code will covert a TIF file into a PNG so you can view it on your local machine.

# %%
pip install --user numpy==1.23.5 opencv-python==4.8.0.76 matplotlib==3.7.1 rasterio
# Out:
# Requirement already satisfied: numpy==1.23.5 in /home/mayers7/.local/lib/python3.9/site-packages (1.23.5)
# Requirement already satisfied: opencv-python==4.8.0.76 in /home/mayers7/.local/lib/python3.9/site-packages (4.8.0.76)
# Requirement already satisfied: matplotlib==3.7.1 in /home/mayers7/.local/lib/python3.9/site-packages (3.7.1)
# Requirement already satisfied: rasterio in /home/mayers7/.local/lib/python3.9/site-packages (1.3.11)
# Requirement already satisfied: contourpy>=1.0.1 in /home/mayers7/.local/lib/python3.9/site-packages (from matplotlib==3.7.1) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /opt/sw/spack/apps/linux-rhel8-x86_64_v2/gcc-10.3.0/python-3.9.9-jh/lib/python3.9/site-packages (from matplotlib==3.7.1) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/sw/spack/apps/linux-rhel8-x86_64_v2/gcc-10.3.0/python-3.9.9-jh/lib/python3.9/site-packages (from matplotlib==3.7.1) (4.31.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/sw/spack/apps/linux-rhel8-x86_64_v2/gcc-10.3.0/python-3.9.9-jh/lib/python3.9/site-packages (from matplotlib==3.7.1) (1.4.0)
# Requirement already satisfied: packaging>=20.0 in /opt/sw/spack/apps/linux-rhel8-x86_64_v2/gcc-10.3.0/python-3.9.9-jh/lib/python3.9/site-packages (from matplotlib==3.7.1) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/sw/spack/apps/linux-rhel8-x86_64_v2/gcc-10.3.0/python-3.9.9-jh/lib/python3.9/site-packages (from matplotlib==3.7.1) (9.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/sw/spack/apps/linux-rhel8-x86_64_v2/gcc-10.3.0/python-3.9.9-jh/lib/python3.9/site-packages (from matplotlib==3.7.1) (3.0.7)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/sw/spack/apps/linux-rhel8-x86_64_v2/gcc-10.3.0/python-3.9.9-jh/lib/python3.9/site-packages (from matplotlib==3.7.1) (2.8.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/mayers7/.local/lib/python3.9/site-packages (from matplotlib==3.7.1) (6.5.2)
# Requirement already satisfied: affine in /home/mayers7/.local/lib/python3.9/site-packages (from rasterio) (2.4.0)
# Requirement already satisfied: attrs in /opt/sw/spack/apps/linux-rhel8-x86_64_v2/gcc-10.3.0/python-3.9.9-jh/lib/python3.9/site-packages (from rasterio) (21.4.0)
# Requirement already satisfied: certifi in /opt/sw/spack/apps/linux-rhel8-x86_64_v2/gcc-10.3.0/python-3.9.9-jh/lib/python3.9/site-packages (from rasterio) (2021.10.8)
# Requirement already satisfied: click>=4.0 in /opt/sw/spack/apps/linux-rhel8-x86_64_v2/gcc-10.3.0/python-3.9.9-jh/lib/python3.9/site-packages (from rasterio) (8.0.4)
# Requirement already satisfied: cligj>=0.5 in /home/mayers7/.local/lib/python3.9/site-packages (from rasterio) (0.7.2)
# Requirement already satisfied: snuggs>=1.4.1 in /home/mayers7/.local/lib/python3.9/site-packages (from rasterio) (1.4.7)
# Requirement already satisfied: click-plugins in /home/mayers7/.local/lib/python3.9/site-packages (from rasterio) (1.1.1)
# Requirement already satisfied: setuptools in /opt/sw/spack/apps/linux-rhel8-x86_64_v2/gcc-10.3.0/python-3.9.9-jh/lib/python3.9/site-packages (from rasterio) (61.0.0)
# Requirement already satisfied: importlib-metadata in /opt/sw/spack/apps/linux-rhel8-x86_64_v2/gcc-10.3.0/python-3.9.9-jh/lib/python3.9/site-packages (from rasterio) (4.11.3)
# Requirement already satisfied: zipp>=3.1.0 in /opt/sw/spack/apps/linux-rhel8-x86_64_v2/gcc-10.3.0/python-3.9.9-jh/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib==3.7.1) (3.7.0)
# Requirement already satisfied: six>=1.5 in /opt/sw/spack/apps/linux-rhel8-x86_64_v2/gcc-10.3.0/python-3.9.9-jh/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib==3.7.1) (1.16.0)
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# AWS API related
import boto3
from botocore import UNSIGNED
from botocore.config import Config
# Work with TIFF format files
import rasterio
# Visualization
import matplotlib.pyplot as plt
# Data manipulation
import numpy as np
# System
import os
from PIL import Image

# %%
# Define input and output file paths
tif_path = "2019_30m_cdls.tif"
png_path = "converted_image.png"

# %%
# Open the TIFF file
with rasterio.open(tif_path) as src:
    image_array = src.read(1)  # Read the single available band

# %%
# Convert to PIL image and save as PNG
image = Image.fromarray(image_array)
image.save(png_path)

# %%
print(f"Saved PNG file as: {png_path}")
# Out:
# Saved PNG file as: converted_image.png
